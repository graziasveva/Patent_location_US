# %% [markdown]
# ### Improving American assignee geolocalization at county level
#
#
# In this notebook I propose some code to create a crawler to improve the geolocalization of patents whose assignee address is in United States. The reason for sharing this lies in the fact that currently most of patent addresses are linked to GeoNames ZIPcodes, hence it is not possible to assign coordinates (or county) to all the  patents whose ZIP codes are not present in Geonames' list (https://www.geonames.org/postal-codes/postal-codes-us.html).
# To improve this current situation, in my patent geolocalization effort I create a crawler to find geographic information for these unmatched ZIP codes through unitedstateszipcodes.org (https://www.unitedstateszipcodes.org/).
#
# In my research work, I managed to assign to an American county almost 98% of all patents granted at USPTO (100% for green patents, defined as such according to WIPO Green Inventory or OECD Green tech definition), which have at least one assignee residing within the US. To create the complete geolocalized (at county level) dataset, starting from the application dataset of patentsview (https://patentsview.org/download/data-download-tables), I used a number of sources:
# 1- raw location data from patentsview (https://patentsview.org/download/data-download-tables)
# 2- USPTO assignee dataset (extracting zipcode from the addresses, where present) (https://assignment.uspto.gov/patent/index.html#/patent/search)
# 3- location dataset by Gaetan de Rassenfosse (https://papers.ssrn.com/sol3/papers.cfm?abstract_id=3425764)
# Then, when even using this sources there wasn't the necessary detail to geolocalize the patent at county level, I used two different strategies:
# 1-in the first place, for those patents missing zipcodes, I recovered them using a public API (https://geo.fcc.gov/api/census/area) to get them using their latitude and longitude
# 2- eventually, for those still lacking county information despite having a zip code, I created a crawler to scrape zip codes from unitedstateszipcodes.org and to get in that way the county of the remaining patents.
#
# The complete dataset of US assigned patents accounts for 4,067,011 obs, including patents granted between 1980 and 2020 and it is available at the following link: https://drive.google.com/drive/folders/1FsDDmwhfARg83SCSVcxeiHylW8h-Er73?usp=sharing
# In the same folder you can also find a dataset about geolocation (US, county level) of green patents (263'630 obs)

# %%
from selenium import webdriver
from selenium.webdriver.firefox.firefox_profile import FirefoxProfile
from selenium.webdriver.firefox.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import WebDriverWait

from bs4 import BeautifulSoup as bs
import time, json
import pandas as pd

# %%
data = pd.read_csv("/allbut30K.csv")#last 30K patents with no county assigned
# Out:
# /home/nicolo/anaconda3/envs/web/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3251: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
nacode = data[(data["county"].isna()) & (data["postcode"].notna())] #Looking for patents with no postcode

# %%
codes = list(set(nacode["postcode"]))

# %%
URL = "https://www.unitedstateszipcodes.org/" #Starting creating the actual crawler for unitedstateszipcodes

# %%
def webDriver(incognito: bool=True, headless: bool=False, 
              geckodriver: str = None,
              tor: bool = True,
              torrc: str = "/etc/tor/torrc"):
    
    options = Options()
    options.headless = headless
    
    if torrc is not None and tor is True:

        options.set_preference("network.proxy.type", 1)
        options.set_preference("network.proxy.socks_version", 5)
        options.set_preference("network.proxy.socks", "127.0.0.1")
        options.set_preference("network.proxy.socks_port", 9050)
        options.set_preference("network.proxy.socks_remote_dns", False)
    
    options.set_preference("network.proxy.type", 1)
    options.set_preference("dom.webdriver.enabled", False)
    options.set_preference("useAutomationExtension", False)
    options.set_preference("devtools.jsonview.enabled", False)

    
    web = webdriver.Firefox(
        options=options,
        executable_path=geckodriver,
    )
    
    web.get("https://check.torproject.org/")
    return web

# %%
d = webDriver(incognito=True, headless=False, geckodriver="./geckodriver_1")
# Out:
# /tmp/ipykernel_14060/1215365368.py:23: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   web = webdriver.Firefox(

# %%
def get_info(webdriver, zipcode):
    
    def city(dict_):
        post_office = dict_["Post Office City"]
        if "(View All Cities)" in post_office:
            post_office = post_office.replace("(View All Cities)", "")
        city, state = post_office.split(",")
        return city.strip(), state.strip()
    
    def county(dict_):
        county = dict_["County"]
        if "County" in county:
            county = county.replace("County", "")
        return county.strip()
    
    def geocode(dict_):
        geoc = dict_["Coordinates"]
        if "ZIP" in geoc:
            geoc = geoc.replace("ZIP", "***")
            a, b = geoc.split("***")

        lat, lon = a.split(",")
        return float(lat.strip()), float(lon.strip())
    
    
    webdriver.get(URL)
    
    input_, info = webdriver.find_element(By.ID, "q"), {}
    webdriver.execute_script('arguments[0].value = "";', input_)
    input_.send_keys(zipcode)
    input_.send_keys(Keys.ENTER)
    time.sleep(1)
    content = bs(webdriver.page_source, "html.parser")
    
    if content.find("div", {"class": "alert alert-danger text-center"}):
        print("Not Found")
        return {"city": "", "state": "", "county": "",
               "latitude": "", "longitude": ""}
    
    try:
        tab = content.find(
            {
                "table": {
                    "class": "table"
                }
            }
        )

        for c in tab.find_all("tr"):
            key = c.find("th")
            value = c.find("td")
            info.update(
                {
                    key.text.strip()[:-1]: value.text.strip()
                }
            )

        try:
            city_, state_ = city(info)
            county_ = county(info)
            lat, lon = geocode(info)    
            i =  {"city": city_, "state": state_, "county": county_,
                   "latitude": lat, "longitude": lon}
            print(f"OK postalcode {zipcode}: {i}")
            return i

        except (KeyError, Exception) as e:
            print(f"ERROR: {e}")
            return {"city": "", "state": "", "county": "",
                   "latitude": "", "longitude": ""}
    except (KeyError, Exception) as e:
        print(f"ERROR: {e}")
        return {"city": "", "state": "", "county": "",
           "latitude": "", "longitude": ""}

# %%
with open("./results.json", "r") as f:
    cod = json.load(f)

# %%
with open("./results.json", "w") as f:
    json.dump(cod, f)

# %%
for code in codes:
    if code not in cod.keys() or not cod[code]["county"]:
        info = get_info(d, code)
        cod.update({code: info})
    else:                   
        continue
# Out:
# Not Found
# Not Found
# Not Found
# Not Found
# ERROR: 'Post Office City'
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# ERROR: local variable 'a' referenced before assignment
# Not Found
# OK postalcode 01845-2649: {'city': 'North Andover', 'state': 'MA', 'county': 'Essex', 'latitude': 42.7, 'longitude': -71.13}
# Not Found
# ERROR: 'Post Office City'
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# ERROR: local variable 'a' referenced before assignment
# ERROR: local variable 'a' referenced before assignment
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# OK postalcode 01983: {'city': 'Topsfield', 'state': 'MA', 'county': 'Essex', 'latitude': 42.64, 'longitude': -70.94}
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# ERROR: local variable 'a' referenced before assignment
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# ERROR: 'Post Office City'
# Not Found
# Not Found
# ERROR: local variable 'a' referenced before assignment
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# ERROR: 'Post Office City'
# ERROR: 'Post Office City'
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# OK postalcode 03086: {'city': 'Wilton', 'state': 'NH', 'county': 'Hillsborough', 'latitude': 42.83, 'longitude': -71.77}
# ERROR: local variable 'a' referenced before assignment
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# ERROR: local variable 'a' referenced before assignment
# ERROR: local variable 'a' referenced before assignment
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# OK postalcode 01842: {'city': 'Lawrence', 'state': 'MA', 'county': 'Essex', 'latitude': 42.71, 'longitude': -71.16}
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# OK postalcode 08837: {'city': 'Edison', 'state': 'NJ', 'county': 'Middlesex', 'latitude': 40.52, 'longitude': -74.34}
# Not Found
# Not Found
# OK postalcode 06106: {'city': 'Hartford', 'state': 'CT', 'county': 'Hartford', 'latitude': 41.74, 'longitude': -72.69}
# Not Found
# Not Found
# Not Found
# Not Found
# ERROR: local variable 'a' referenced before assignment
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# ERROR: local variable 'a' referenced before assignment
# ERROR: local variable 'a' referenced before assignment
# OK postalcode 06795: {'city': 'Watertown', 'state': 'CT', 'county': 'Litchfield', 'latitude': 41.62, 'longitude': -73.12}
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# ERROR: local variable 'a' referenced before assignment
# Not Found
# Not Found
# ERROR: 'County'
# Not Found
# OK postalcode 08809-4000: {'city': 'Annandale', 'state': 'NJ', 'county': 'Hunterdon', 'latitude': 40.64, 'longitude': -74.9}
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# ERROR: local variable 'a' referenced before assignment
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# ERROR: 'Post Office City'
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# ERROR: 'County'
# Not Found
# Not Found
# ERROR: local variable 'a' referenced before assignment
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# OK postalcode 02136: {'city': 'Hyde Park', 'state': 'MA', 'county': 'Suffolk', 'latitude': 42.25, 'longitude': -71.13}
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# OK postalcode 06068: {'city': 'Salisbury', 'state': 'CT', 'county': 'Litchfield', 'latitude': 42.01, 'longitude': -73.42}
# Not Found
# Not Found
# Not Found
# OK postalcode 02909-2499: {'city': 'Providence', 'state': 'RI', 'county': 'Providence', 'latitude': 41.82, 'longitude': -71.44}
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# OK postalcode 07656-8003: {'city': 'Park Ridge', 'state': 'NJ', 'county': 'Bergen', 'latitude': 41.04, 'longitude': -74.04}
# Not Found
# Not Found
# Not Found
# Not Found
# ERROR: local variable 'a' referenced before assignment
# Not Found
# ERROR: local variable 'a' referenced before assignment
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# ERROR: 'Post Office City'
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# ERROR: 'Post Office City'
# Not Found
# ERROR: local variable 'a' referenced before assignment
# Not Found
# Not Found
# ERROR: local variable 'a' referenced before assignment
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# ERROR: 'NoneType' object has no attribute 'find_all'
# OK postalcode 04614: {'city': 'Blue Hill', 'state': 'ME', 'county': 'Hancock', 'latitude': 44.4, 'longitude': -68.6}
# Not Found
# Not Found
# Not Found
# Not Found
# ERROR: 'Post Office City'
# Not Found
# Not Found
# ERROR: local variable 'a' referenced before assignment
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# OK postalcode 06075: {'city': 'Stafford', 'state': 'CT', 'county': 'Tolland', 'latitude': 42.0, 'longitude': -72.3}
# OK postalcode 06813-1966: {'city': 'Danbury', 'state': 'CT', 'county': 'Fairfield', 'latitude': 41.38, 'longitude': -73.48}
# OK postalcode 03110-6908: {'city': 'Bedford', 'state': 'NH', 'county': 'Hillsborough', 'latitude': 42.96, 'longitude': -71.49}
# Not Found
# OK postalcode 07072: {'city': 'Carlstadt', 'state': 'NJ', 'county': 'Bergen', 'latitude': 40.82, 'longitude': -74.07}
# OK postalcode 07005: {'city': 'Boonton', 'state': 'NJ', 'county': 'Morris', 'latitude': 40.92, 'longitude': -74.42}
# ERROR: 'Post Office City'
# ERROR: local variable 'a' referenced before assignment
# Not Found
# OK postalcode 02347: {'city': 'Lakeville', 'state': 'MA', 'county': 'Plymouth', 'latitude': 41.84, 'longitude': -70.97}
# Not Found
# Not Found
# OK postalcode 02481: {'city': 'Wellesley Hills', 'state': 'MA', 'county': 'Norfolk', 'latitude': 42.32, 'longitude': -71.26}
# OK postalcode 01886: {'city': 'Westford', 'state': 'MA', 'county': 'Middlesex', 'latitude': 42.59, 'longitude': -71.44}
# OK postalcode 07670: {'city': 'Tenafly', 'state': 'NJ', 'county': 'Bergen', 'latitude': 40.92, 'longitude': -73.96}
# OK postalcode 03905: {'city': 'Kittery Point', 'state': 'ME', 'county': 'York', 'latitude': 43.09, 'longitude': -70.69}
# OK postalcode 01742: {'city': 'Concord', 'state': 'MA', 'county': 'Middlesex', 'latitude': 42.46, 'longitude': -71.36}
# OK postalcode 02649: {'city': 'Mashpee', 'state': 'MA', 'county': 'Barnstable', 'latitude': 41.61, 'longitude': -70.49}
# OK postalcode 06138-0379: {'city': 'East Hartford', 'state': 'CT', 'county': 'Hartford', 'latitude': 41.77, 'longitude': -72.6}
# OK postalcode 04071: {'city': 'Raymond', 'state': 'ME', 'county': 'Cumberland', 'latitude': 43.9, 'longitude': -70.5}
# OK postalcode 03108: {'city': 'Manchester', 'state': 'NH', 'county': 'Hillsborough', 'latitude': 42.99, 'longitude': -71.47}
# OK postalcode 08103: {'city': 'Camden', 'state': 'NJ', 'county': 'Camden', 'latitude': 39.93, 'longitude': -75.11}
# OK postalcode 01746-2029: {'city': 'Holliston', 'state': 'MA', 'county': 'Middlesex', 'latitude': 42.2, 'longitude': -71.43}
# OK postalcode 01702-5406: {'city': 'Framingham', 'state': 'MA', 'county': 'Middlesex', 'latitude': 42.28, 'longitude': -71.42}
# OK postalcode 06831-5118: {'city': 'Greenwich', 'state': 'CT', 'county': 'Fairfield', 'latitude': 41.03, 'longitude': -73.67}
# Not Found
# OK postalcode 08234-4075: {'city': 'Egg Harbor Township', 'state': 'NJ', 'county': 'Atlantic', 'latitude': 39.4, 'longitude': -74.6}
# OK postalcode 01590: {'city': 'Sutton', 'state': 'MA', 'county': 'Worcester', 'latitude': 42.14, 'longitude': -71.76}
# ERROR: local variable 'a' referenced before assignment
# OK postalcode 06468-2412: {'city': 'Monroe', 'state': 'CT', 'county': 'Fairfield', 'latitude': 41.34, 'longitude': -73.25}
# OK postalcode 01748-9103: {'city': 'Hopkinton', 'state': 'MA', 'county': 'Middlesex', 'latitude': 42.23, 'longitude': -71.53}
# OK postalcode 03070: {'city': 'New Boston', 'state': 'NH', 'county': 'Hillsborough', 'latitude': 42.98, 'longitude': -71.69}
# OK postalcode 04105: {'city': 'Falmouth', 'state': 'ME', 'county': 'Cumberland', 'latitude': 43.75, 'longitude': -70.27}
# OK postalcode 60880: {'city': '', 'state': '', 'county': 'Oise', 'latitude': 49.38, 'longitude': 2.76}
# OK postalcode 05250-4465: {'city': 'Arlington', 'state': 'VT', 'county': 'Bennington', 'latitude': 43.1, 'longitude': -73.2}
# OK postalcode 01453: {'city': 'Leominster', 'state': 'MA', 'county': 'Worcester', 'latitude': 42.52, 'longitude': -71.77}
# OK postalcode 07643-1901: {'city': 'Little Ferry', 'state': 'NJ', 'county': 'Bergen', 'latitude': 40.85, 'longitude': -74.04}
# OK postalcode 08817-6007: {'city': 'Edison', 'state': 'NJ', 'county': 'Middlesex', 'latitude': 40.51, 'longitude': -74.4}
# Not Found
# Not Found
# OK postalcode 03867: {'city': 'Rochester', 'state': 'NH', 'county': 'Strafford', 'latitude': 43.3, 'longitude': -70.99}
# OK postalcode 02464: {'city': 'Newton Upper Falls', 'state': 'MA', 'county': 'Middlesex', 'latitude': 42.313, 'longitude': -71.22}
# OK postalcode 02347-1232: {'city': 'Lakeville', 'state': 'MA', 'county': 'Plymouth', 'latitude': 41.82, 'longitude': -70.96}
# OK postalcode 82131: {'city': '', 'state': '', 'county': 'Starnberg', 'latitude': 48.0, 'longitude': 11.4}
# OK postalcode 01853: {'city': 'Lowell', 'state': 'MA', 'county': 'Middlesex', 'latitude': 42.63, 'longitude': -71.3}
# OK postalcode 02124: {'city': 'Dorchester Center', 'state': 'MA', 'county': 'Suffolk', 'latitude': 42.29, 'longitude': -71.07}
# OK postalcode 06266: {'city': 'South Windham', 'state': 'CT', 'county': 'Windham', 'latitude': 41.67, 'longitude': -72.15}
# Not Found
# Not Found
# Not Found
# OK postalcode 05473: {'city': 'North Ferrisburgh', 'state': 'VT', 'county': 'Addison', 'latitude': 44.23, 'longitude': -73.2}
# OK postalcode 01863: {'city': 'North Chelmsford', 'state': 'MA', 'county': 'Middlesex', 'latitude': 42.63, 'longitude': -71.39}
# Not Found
# OK postalcode 01842-2336: {'city': 'Lawrence', 'state': 'MA', 'county': 'Essex', 'latitude': 42.71, 'longitude': -71.17}
# OK postalcode 04332: {'city': 'Augusta', 'state': 'ME', 'county': 'Kennebec', 'latitude': 44.4, 'longitude': -69.7}
# Not Found
# OK postalcode 09302: {'city': 'Apo', 'state': 'AE', 'county': 'Landkreis Mittelsachsen', 'latitude': 51.0, 'longitude': 12.8}
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# OK postalcode 02721: {'city': 'Fall River', 'state': 'MA', 'county': 'Bristol', 'latitude': 41.65, 'longitude': -71.15}
# OK postalcode 03051-4922: {'city': 'Hudson', 'state': 'NH', 'county': 'Hillsborough', 'latitude': 42.76, 'longitude': -71.44}
# Not Found
# Not Found
# OK postalcode USA 07480: {'city': 'West Milford', 'state': 'NJ', 'county': 'Passaic', 'latitude': 41.13, 'longitude': -74.37}
# OK postalcode 07933: {'city': 'Gillette', 'state': 'NJ', 'county': 'Morris', 'latitude': 40.69, 'longitude': -74.47}
# OK postalcode 02860: {'city': 'Pawtucket', 'state': 'RI', 'county': 'Providence', 'latitude': 41.88, 'longitude': -71.39}
# OK postalcode US 06103: {'city': 'Hartford', 'state': 'CT', 'county': 'Hartford', 'latitude': 41.77, 'longitude': -72.68}
# Not Found
# OK postalcode USA 07834: {'city': 'Denville', 'state': 'NJ', 'county': 'Morris', 'latitude': 40.89, 'longitude': -74.48}
# Not Found
# OK postalcode 02468: {'city': 'Waban', 'state': 'MA', 'county': 'Middlesex', 'latitude': 42.33, 'longitude': -71.23}
# Not Found
# Not Found
# Not Found
# Not Found
# OK postalcode 37251: {'city': '', 'state': '', 'county': 'Werra-Meissner-Kreis', 'latitude': 51.19, 'longitude': 10.04}
# OK postalcode 01887: {'city': 'Wilmington', 'state': 'MA', 'county': 'Middlesex', 'latitude': 42.57, 'longitude': -71.17}
# OK postalcode 05677: {'city': 'Waterbury Center', 'state': 'VT', 'county': 'Washington', 'latitude': 44.39, 'longitude': -72.71}
# Not Found
# OK postalcode 05067: {'city': 'South Pomfret', 'state': 'VT', 'county': 'Windsor', 'latitude': 43.7, 'longitude': -72.56}
# OK postalcode 02818-1536: {'city': 'East Greenwich', 'state': 'RI', 'county': 'Kent', 'latitude': 41.66, 'longitude': -71.45}
# OK postalcode 07652-3556: {'city': 'Paramus', 'state': 'NJ', 'county': 'Bergen', 'latitude': 40.97, 'longitude': -74.08}
# Not Found
# Not Found
# OK postalcode 02865-4253: {'city': 'Lincoln', 'state': 'RI', 'county': 'Providence', 'latitude': 41.9, 'longitude': -71.41}
# Not Found
# OK postalcode 01108: {'city': 'Springfield', 'state': 'MA', 'county': 'Hampden', 'latitude': 42.08, 'longitude': -72.56}
# Not Found
# Not Found
# Not Found
# OK postalcode 09123: {'city': 'Apo', 'state': 'AE', 'county': 'Kreisfreie Stadt Chemnitz', 'latitude': 50.77, 'longitude': 12.93}
# Not Found
# OK postalcode 30379: {'city': 'Atlanta', 'state': 'GA', 'county': 'Fulton', 'latitude': 33.75, 'longitude': -84.39}
# OK postalcode 02205: {'city': 'Boston', 'state': 'MA', 'county': 'Suffolk', 'latitude': 42.359, 'longitude': -71.057}
# Not Found
# Not Found
# OK postalcode 01007: {'city': 'Belchertown', 'state': 'MA', 'county': 'Hampshire', 'latitude': 42.3, 'longitude': -72.4}
# OK postalcode 06088: {'city': 'East Windsor', 'state': 'CT', 'county': 'Hartford', 'latitude': 41.9, 'longitude': -72.59}
# OK postalcode 04033: {'city': 'Freeport', 'state': 'ME', 'county': 'Cumberland', 'latitude': 43.856, 'longitude': -70.106}
# OK postalcode 23542: {'city': '', 'state': '', 'county': 'Lubeck', 'latitude': 53.87, 'longitude': 10.69}
# OK postalcode 01950: {'city': 'Newburyport', 'state': 'MA', 'county': 'Essex', 'latitude': 42.81, 'longitude': -70.87}
# OK postalcode 06042: {'city': 'Manchester', 'state': 'CT', 'county': 'Hartford', 'latitude': 41.8, 'longitude': -72.53}
# OK postalcode 77678: {'city': '', 'state': '', 'county': 'Ortenaukreis', 'latitude': 48.6, 'longitude': 7.9}
# OK postalcode 02456: {'city': 'New Town', 'state': 'MA', 'county': 'Middlesex', 'latitude': 42.33, 'longitude': -71.18}
# Not Found
# Not Found
# OK postalcode 01805: {'city': 'Burlington', 'state': 'MA', 'county': 'Middlesex', 'latitude': 42.51, 'longitude': -71.2}
# OK postalcode 07201: {'city': 'Elizabeth', 'state': 'NJ', 'county': 'Union', 'latitude': 40.67, 'longitude': -74.18}
# OK postalcode 06705: {'city': 'Waterbury', 'state': 'CT', 'county': 'New Haven', 'latitude': 41.55, 'longitude': -72.99}
# Not Found
# Not Found
# Not Found
# ERROR: local variable 'a' referenced before assignment
# OK postalcode 08011: {'city': 'Birmingham', 'state': 'NJ', 'county': 'Burlington', 'latitude': 39.96, 'longitude': -74.65}
# Not Found
# OK postalcode 01324: {'city': '', 'state': '', 'county': 'Kreisfreie Stadt Dresden', 'latitude': 51.07, 'longitude': 13.86}
# OK postalcode 07869: {'city': 'Randolph', 'state': 'NJ', 'county': 'Morris', 'latitude': 40.85, 'longitude': -74.59}
# OK postalcode 05153: {'city': 'Proctorsville', 'state': 'VT', 'county': 'Windsor', 'latitude': 43.4, 'longitude': -72.6}
# Not Found
# Not Found
# OK postalcode 07940-1027: {'city': 'Madison', 'state': 'NJ', 'county': 'Morris', 'latitude': 40.76, 'longitude': -74.42}
# OK postalcode 01451: {'city': 'Harvard', 'state': 'MA', 'county': 'Worcester', 'latitude': 42.5, 'longitude': -71.58}
# OK postalcode 08724: {'city': 'Brick', 'state': 'NJ', 'county': 'Ocean', 'latitude': 40.1, 'longitude': -74.11}
# OK postalcode 01432: {'city': 'Ayer', 'state': 'MA', 'county': 'Middlesex', 'latitude': 42.56, 'longitude': -71.57}
# Not Found
# OK postalcode 02460: {'city': 'Newtonville', 'state': 'MA', 'county': 'Middlesex', 'latitude': 42.35, 'longitude': -71.21}
# Not Found
# OK postalcode 01833: {'city': 'Georgetown', 'state': 'MA', 'county': 'Essex', 'latitude': 42.72, 'longitude': -70.98}
# OK postalcode 06513: {'city': 'New Haven', 'state': 'CT', 'county': 'New Haven', 'latitude': 41.32, 'longitude': -72.86}
# OK postalcode 06890: {'city': 'Southport', 'state': 'CT', 'county': 'Fairfield', 'latitude': 41.14, 'longitude': -73.29}
# OK postalcode 06111: {'city': 'Newington', 'state': 'CT', 'county': 'Hartford', 'latitude': 41.69, 'longitude': -72.73}
# Not Found
# OK postalcode 03848: {'city': 'Kingston', 'state': 'NH', 'county': 'Rockingham', 'latitude': 42.91, 'longitude': -71.06}
# OK postalcode 02461-1951: {'city': 'Newton Highlands', 'state': 'MA', 'county': 'Middlesex', 'latitude': 42.32, 'longitude': -71.21}
# OK postalcode 02061-1605: {'city': 'Norwell', 'state': 'MA', 'county': 'Plymouth', 'latitude': 42.17, 'longitude': -70.88}
# OK postalcode 23904-3127: {'city': 'Hayesville', 'state': 'NC', 'county': 'Clay', 'latitude': 35.0, 'longitude': -83.8}
# OK postalcode 02478-2323: {'city': 'Belmont', 'state': 'MA', 'county': 'Middlesex', 'latitude': 42.39, 'longitude': -71.18}
# Not Found
# OK postalcode USA 02129: {'city': 'Charlestown', 'state': 'MA', 'county': 'Suffolk', 'latitude': 42.38, 'longitude': -71.06}
# OK postalcode 06114: {'city': 'Hartford', 'state': 'CT', 'county': 'Hartford', 'latitude': 41.75, 'longitude': -72.67}
# OK postalcode 03856: {'city': 'Newfields', 'state': 'NH', 'county': 'Rockingham', 'latitude': 43.04, 'longitude': -70.96}
# OK postalcode 07074: {'city': 'Moonachie', 'state': 'NJ', 'county': 'Bergen', 'latitude': 40.84, 'longitude': -74.06}
# OK postalcode 02895-1833: {'city': 'Woonsocket', 'state': 'RI', 'county': 'Providence', 'latitude': 42.0, 'longitude': -71.51}
# OK postalcode 01570: {'city': 'Webster', 'state': 'MA', 'county': 'Worcester', 'latitude': 42.06, 'longitude': -71.85}
# Not Found
# OK postalcode 08628: {'city': 'Trenton', 'state': 'NJ', 'county': 'Mercer', 'latitude': 40.27, 'longitude': -74.82}
# Not Found
# OK postalcode U.S.A. 01742: {'city': 'Concord', 'state': 'MA', 'county': 'Middlesex', 'latitude': 42.46, 'longitude': -71.35}
# Not Found
# Not Found
# OK postalcode 07009: {'city': 'Cedar Grove', 'state': 'NJ', 'county': 'Essex', 'latitude': 40.86, 'longitude': -74.23}
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# OK postalcode 01731-4075: {'city': 'Hanscom AFB', 'state': 'MA', 'county': 'Middlesex', 'latitude': 42.46, 'longitude': -71.28}
# OK postalcode 07045-1000: {'city': 'Montville', 'state': 'NJ', 'county': 'Morris', 'latitude': 40.89, 'longitude': -74.37}
# ERROR: local variable 'a' referenced before assignment
# OK postalcode USA 02109: {'city': 'Boston', 'state': 'MA', 'county': 'Suffolk', 'latitude': 42.36, 'longitude': -71.055}
# OK postalcode 10067: {'city': '', 'state': '', 'county': 'Aube', 'latitude': 48.29, 'longitude': 4.08}
# ERROR: 'Post Office City'
# Not Found
# OK postalcode 01944: {'city': 'Manchester', 'state': 'MA', 'county': 'Essex', 'latitude': 42.58, 'longitude': -70.76}
# OK postalcode 02809-2721: {'city': 'Bristol', 'state': 'RI', 'county': 'Bristol', 'latitude': 41.68, 'longitude': -71.27}
# OK postalcode 08034-3836: {'city': 'Cherry Hill', 'state': 'NJ', 'county': 'Camden', 'latitude': 39.92, 'longitude': -75.0}
# OK postalcode 07417: {'city': 'Franklin Lakes', 'state': 'NJ', 'county': 'Bergen', 'latitude': 41.01, 'longitude': -74.21}
# OK postalcode 03906: {'city': 'North Berwick', 'state': 'ME', 'county': 'York', 'latitude': 43.3, 'longitude': -70.8}
# OK postalcode 07311: {'city': 'Jersey City', 'state': 'NJ', 'county': 'Hudson', 'latitude': 40.719, 'longitude': -74.034}
# OK postalcode 07652: {'city': 'Paramus', 'state': 'NJ', 'county': 'Bergen', 'latitude': 40.94, 'longitude': -74.07}
# OK postalcode 19830: {'city': '', 'state': '', 'county': 'Echapora', 'latitude': -22.4, 'longitude': -50.2}
# OK postalcode 01702: {'city': 'Framingham', 'state': 'MA', 'county': 'Middlesex', 'latitude': 42.28, 'longitude': -71.44}
# ERROR: 'Post Office City'
# OK postalcode 06902: {'city': 'Stamford', 'state': 'CT', 'county': 'Fairfield', 'latitude': 41.06, 'longitude': -73.54}
# OK postalcode 05253: {'city': 'East Dorset', 'state': 'VT', 'county': 'Bennington', 'latitude': 43.3, 'longitude': -73.0}
# OK postalcode 04112-5415: {'city': 'Portland', 'state': 'ME', 'county': 'Cumberland', 'latitude': 43.66, 'longitude': -70.26}
# OK postalcode 08080: {'city': 'Sewell', 'state': 'NJ', 'county': 'Gloucester', 'latitude': 39.76, 'longitude': -75.12}
# OK postalcode 92718: {'city': '', 'state': '', 'county': 'Neustadt an der Waldnaab', 'latitude': 49.65, 'longitude': 12.18}
# ERROR: local variable 'a' referenced before assignment
# OK postalcode 06855: {'city': 'Norwalk', 'state': 'CT', 'county': 'Fairfield', 'latitude': 41.1, 'longitude': -73.4}
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# OK postalcode 02536: {'city': 'East Falmouth', 'state': 'MA', 'county': 'Barnstable', 'latitude': 41.6, 'longitude': -70.56}
# Not Found
# OK postalcode 03057: {'city': 'Mont Vernon', 'state': 'NH', 'county': 'Hillsborough', 'latitude': 42.9, 'longitude': -71.69}
# OK postalcode 01581: {'city': 'Westborough', 'state': 'MA', 'county': 'Worcester', 'latitude': 42.27, 'longitude': -71.61}
# Not Found
# OK postalcode 06103-3207: {'city': 'Hartford', 'state': 'CT', 'county': 'Hartford', 'latitude': 41.77, 'longitude': -72.68}
# OK postalcode 08732: {'city': 'Island Heights', 'state': 'NJ', 'county': 'Ocean', 'latitude': 39.94, 'longitude': -74.15}
# OK postalcode 08042: {'city': 'Juliustown', 'state': 'NJ', 'county': 'Burlington', 'latitude': 40.03, 'longitude': -74.69}
# ERROR: local variable 'a' referenced before assignment
# OK postalcode 08003-3157: {'city': 'Cherry Hill', 'state': 'NJ', 'county': 'Camden', 'latitude': 39.9, 'longitude': -74.97}
# OK postalcode 01541: {'city': 'Princeton', 'state': 'MA', 'county': 'Worcester', 'latitude': 42.46, 'longitude': -71.89}
# Not Found
# Not Found
# Not Found
# Not Found
# OK postalcode 07463-1512: {'city': 'Waldwick', 'state': 'NJ', 'county': 'Bergen', 'latitude': 41.01, 'longitude': -74.12}
# OK postalcode 03032-3724: {'city': 'Auburn', 'state': 'NH', 'county': 'Rockingham', 'latitude': 43.01, 'longitude': -71.39}
# OK postalcode 04008: {'city': 'Bowdoinham', 'state': 'ME', 'county': 'Sagadahoc', 'latitude': 44.03, 'longitude': -69.87}
# OK postalcode 03051: {'city': 'Hudson', 'state': 'NH', 'county': 'Hillsborough', 'latitude': 42.76, 'longitude': -71.41}
# OK postalcode 02108: {'city': 'Boston', 'state': 'MA', 'county': 'Suffolk', 'latitude': 42.358, 'longitude': -71.064}
# OK postalcode 02113: {'city': 'Boston', 'state': 'MA', 'county': 'Suffolk', 'latitude': 42.365, 'longitude': -71.055}
# Not Found
# OK postalcode 96665: {'city': 'Fpo', 'state': 'AP', 'county': 'Contra Costa', 'latitude': 37.9, 'longitude': -122.32}
# OK postalcode USA 01960: {'city': 'Peabody', 'state': 'MA', 'county': 'Essex', 'latitude': 42.52, 'longitude': -70.93}
# OK postalcode 05302-6212: {'city': 'Brattleboro', 'state': 'VT', 'county': 'Windham', 'latitude': 42.85, 'longitude': -72.56}
# OK postalcode 07465: {'city': 'Wanaque', 'state': 'NJ', 'county': 'Passaic', 'latitude': 41.05, 'longitude': -74.29}
# OK postalcode 02779: {'city': 'Berkley', 'state': 'MA', 'county': 'Bristol', 'latitude': 41.83, 'longitude': -71.06}
# OK postalcode 05733: {'city': 'Brandon', 'state': 'VT', 'county': 'Rutland', 'latitude': 43.8, 'longitude': -73.1}
# ERROR: 'NoneType' object has no attribute 'find_all'
# ERROR: 'NoneType' object has no attribute 'find_all'
# Not Found
# OK postalcode 02763-0300: {'city': 'Attleboro Falls', 'state': 'MA', 'county': 'Bristol', 'latitude': 41.97, 'longitude': -71.3}
# Not Found
# OK postalcode 06115: {'city': 'Hartford', 'state': 'CT', 'county': 'Hartford', 'latitude': 41.77, 'longitude': -72.67}
# Not Found
# Not Found
# Not Found
# OK postalcode 01731: {'city': 'Hanscom AFB', 'state': 'MA', 'county': 'Middlesex', 'latitude': 42.46, 'longitude': -71.28}
# Not Found
# OK postalcode 07310: {'city': 'Jersey City', 'state': 'NJ', 'county': 'Hudson', 'latitude': 40.73, 'longitude': -74.04}
# OK postalcode 06416-2074: {'city': 'Cromwell', 'state': 'CT', 'county': 'Middlesex', 'latitude': 41.61, 'longitude': -72.68}
# OK postalcode 08318-4563: {'city': 'Elmer', 'state': 'NJ', 'county': 'Salem', 'latitude': 39.6, 'longitude': -75.2}
# ERROR: 'NoneType' object has no attribute 'find_all'
# OK postalcode 05862: {'city': 'Peacham', 'state': 'VT', 'county': 'Caledonia', 'latitude': 44.33, 'longitude': -72.16}
# Not Found
# Not Found
# OK postalcode 03846: {'city': 'Jackson', 'state': 'NH', 'county': 'Carroll', 'latitude': 44.19, 'longitude': -71.18}
# OK postalcode 03840: {'city': 'Greenland', 'state': 'NH', 'county': 'Rockingham', 'latitude': 43.03, 'longitude': -70.85}
# OK postalcode 06416-2072: {'city': 'Cromwell', 'state': 'CT', 'county': 'Middlesex', 'latitude': 41.61, 'longitude': -72.68}
# OK postalcode 07069: {'city': 'Watchung', 'state': 'NJ', 'county': 'Somerset', 'latitude': 40.64, 'longitude': -74.44}
# Not Found
# OK postalcode 02879: {'city': 'Wakefield', 'state': 'RI', 'county': 'Washington', 'latitude': 41.43, 'longitude': -71.54}
# OK postalcode 02647: {'city': 'Hyannis Port', 'state': 'MA', 'county': 'Barnstable', 'latitude': 41.632, 'longitude': -70.302}
# OK postalcode 01238: {'city': 'Lee', 'state': 'MA', 'county': 'Berkshire', 'latitude': 42.3, 'longitude': -73.22}
# OK postalcode US 02351: {'city': 'Abington', 'state': 'MA', 'county': 'Plymouth', 'latitude': 42.13, 'longitude': -70.94}
# Not Found
# Not Found
# OK postalcode 08330: {'city': 'Mays Landing', 'state': 'NJ', 'county': 'Atlantic', 'latitude': 39.5, 'longitude': -74.7}
# OK postalcode 02026-6797: {'city': 'Dedham', 'state': 'MA', 'county': 'Norfolk', 'latitude': 42.25, 'longitude': -71.17}
# OK postalcode 03106: {'city': 'Hooksett', 'state': 'NH', 'county': 'Merrimack', 'latitude': 43.07, 'longitude': -71.44}
# Not Found
# OK postalcode 01027: {'city': 'Easthampton', 'state': 'MA', 'county': 'Hampshire', 'latitude': 42.3, 'longitude': -72.7}
# OK postalcode 01608: {'city': 'Worcester', 'state': 'MA', 'county': 'Worcester', 'latitude': 42.26, 'longitude': -71.8}
# OK postalcode 06776: {'city': 'New Milford', 'state': 'CT', 'county': 'Litchfield', 'latitude': 41.6, 'longitude': -73.4}
# OK postalcode 01469-8001: {'city': 'Townsend', 'state': 'MA', 'county': 'Middlesex', 'latitude': 42.67, 'longitude': -71.71}
# OK postalcode 01013: {'city': 'Chicopee', 'state': 'MA', 'county': 'Hampden', 'latitude': 42.16, 'longitude': -72.6}
# OK postalcode 08863-0602: {'city': 'Fords', 'state': 'NJ', 'county': 'Middlesex', 'latitude': 40.53, 'longitude': -74.31}
# OK postalcode 06103: {'city': 'Hartford', 'state': 'CT', 'county': 'Hartford', 'latitude': 41.77, 'longitude': -72.68}
# OK postalcode 07801: {'city': 'Dover', 'state': 'NJ', 'county': 'Morris', 'latitude': 40.89, 'longitude': -74.55}
# Not Found
# OK postalcode 08124: {'city': '', 'state': '', 'county': 'Landkreis Zwickau', 'latitude': 50.67, 'longitude': 12.49}
# OK postalcode 07748: {'city': 'Middletown', 'state': 'NJ', 'county': 'Monmouth', 'latitude': 40.4, 'longitude': -74.11}
# Not Found
# Not Found
# OK postalcode 06477: {'city': 'Orange', 'state': 'CT', 'county': 'New Haven', 'latitude': 41.26, 'longitude': -73.0}
# OK postalcode 05641: {'city': 'Barre', 'state': 'VT', 'county': 'Washington', 'latitude': 44.2, 'longitude': -72.4}
# OK postalcode USA 07083: {'city': 'Union', 'state': 'NJ', 'county': 'Union', 'latitude': 40.7, 'longitude': -74.27}
# Not Found
# Not Found
# Not Found
# Not Found
# OK postalcode 08808: {'city': 'Broadway', 'state': 'NJ', 'county': 'Warren', 'latitude': 40.76, 'longitude': -75.01}
# OK postalcode 07470: {'city': 'Wayne', 'state': 'NJ', 'county': 'Passaic', 'latitude': 40.95, 'longitude': -74.24}
# OK postalcode 08109-1399: {'city': 'Merchantville', 'state': 'NJ', 'county': 'Camden', 'latitude': 39.93, 'longitude': -75.07}
# Not Found
# OK postalcode 05401-4985: {'city': 'Burlington', 'state': 'VT', 'county': 'Chittenden', 'latitude': 44.48, 'longitude': -73.21}
# OK postalcode 07013: {'city': 'Clifton', 'state': 'NJ', 'county': 'Passaic', 'latitude': 40.87, 'longitude': -74.17}
# OK postalcode 06260: {'city': 'Putnam', 'state': 'CT', 'county': 'Windham', 'latitude': 41.9, 'longitude': -71.87}
# OK postalcode 65929: {'city': '', 'state': '', 'county': 'Frankfurt', 'latitude': 50.09, 'longitude': 8.53}
# OK postalcode 08034: {'city': 'Cherry Hill', 'state': 'NJ', 'county': 'Camden', 'latitude': 39.91, 'longitude': -75.0}
# OK postalcode 79202: {'city': '', 'state': '', 'county': 'Breisgau-Hochschwarzwald', 'latitude': 48.0, 'longitude': 7.6}
# Not Found
# ERROR: 'NoneType' object has no attribute 'find_all'
# OK postalcode 04330: {'city': 'Augusta', 'state': 'ME', 'county': 'Kennebec', 'latitude': 44.4, 'longitude': -69.7}
# Not Found
# OK postalcode 06820-5900: {'city': 'Darien', 'state': 'CT', 'county': 'Fairfield', 'latitude': 41.08, 'longitude': -73.47}
# OK postalcode 01606: {'city': 'Worcester', 'state': 'MA', 'county': 'Worcester', 'latitude': 42.31, 'longitude': -71.8}
# OK postalcode 08896: {'city': '', 'state': '', 'county': 'Somerset', 'latitude': 40.57, 'longitude': -74.64}
# OK postalcode 07109: {'city': 'Belleville', 'state': 'NJ', 'county': 'Essex', 'latitude': 40.79, 'longitude': -74.16}
# OK postalcode 03809: {'city': 'Alton', 'state': 'NH', 'county': 'Belknap', 'latitude': 43.5, 'longitude': -71.2}
# OK postalcode 02149: {'city': 'Everett', 'state': 'MA', 'county': 'Middlesex', 'latitude': 42.41, 'longitude': -71.05}
# Not Found
# Not Found
# OK postalcode 06450: {'city': 'Meriden', 'state': 'CT', 'county': 'New Haven', 'latitude': 41.54, 'longitude': -72.78}
# Not Found
# OK postalcode 01749: {'city': 'Hudson', 'state': 'MA', 'county': 'Middlesex', 'latitude': 42.39, 'longitude': -71.54}
# Not Found
# Not Found
# Not Found
# OK postalcode 05060: {'city': 'Randolph', 'state': 'VT', 'county': 'Orange', 'latitude': 44.0, 'longitude': -72.7}
# OK postalcode 03470: {'city': 'Winchester', 'state': 'NH', 'county': 'Cheshire', 'latitude': 42.8, 'longitude': -72.3}
# Not Found
# OK postalcode USA 02464: {'city': 'Newton Upper Falls', 'state': 'MA', 'county': 'Middlesex', 'latitude': 42.313, 'longitude': -71.22}
# Not Found
# ERROR: local variable 'a' referenced before assignment
# OK postalcode 9136: {'city': '', 'state': '', 'county': 'Diekirch', 'latitude': 49.829, 'longitude': 6.098}
# Not Found
# ERROR: 'Post Office City'
# Not Found
# OK postalcode 08081: {'city': 'Sicklerville', 'state': 'NJ', 'county': 'Camden', 'latitude': 39.74, 'longitude': -74.97}
# OK postalcode 01835: {'city': 'Haverhill', 'state': 'MA', 'county': 'Essex', 'latitude': 42.75, 'longitude': -71.09}
# OK postalcode 06110: {'city': 'West Hartford', 'state': 'CT', 'county': 'Hartford', 'latitude': 41.73, 'longitude': -72.74}
# OK postalcode 06336: {'city': 'Gilman', 'state': 'CT', 'county': 'New London', 'latitude': 41.58, 'longitude': -72.19}
# Not Found
# Not Found
# OK postalcode 07206: {'city': 'Elizabethport', 'state': 'NJ', 'county': 'Union', 'latitude': 40.67, 'longitude': -74.17}
# Not Found
# OK postalcode 07630: {'city': 'Emerson', 'state': 'NJ', 'county': 'Bergen', 'latitude': 40.97, 'longitude': -74.02}
# OK postalcode 08543-4000: {'city': 'Princeton', 'state': 'NJ', 'county': 'Mercer', 'latitude': 50.56, 'longitude': 12.173}
# OK postalcode 06794: {'city': 'Washington Depot', 'state': 'CT', 'county': 'Litchfield', 'latitude': 41.65, 'longitude': -73.32}
# OK postalcode 06087: {'city': 'Unionville', 'state': 'CT', 'county': 'Hartford', 'latitude': 41.75, 'longitude': -72.89}
# ERROR: local variable 'a' referenced before assignment
# OK postalcode 02891: {'city': 'Westerly', 'state': 'RI', 'county': 'Washington', 'latitude': 41.36, 'longitude': -71.8}
# OK postalcode 02462: {'city': 'Newton Lower Falls', 'state': 'MA', 'county': 'Middlesex', 'latitude': 42.33, 'longitude': -71.26}
# Not Found
# OK postalcode 08005: {'city': 'Barnegat', 'state': 'NJ', 'county': 'Ocean', 'latitude': 39.8, 'longitude': -74.3}
# OK postalcode 06756: {'city': 'Goshen', 'state': 'CT', 'county': 'Litchfield', 'latitude': 41.85, 'longitude': -73.23}
# OK postalcode 07942-0636: {'city': 'Harmony', 'state': 'ME', 'county': 'Somerset', 'latitude': 45.0, 'longitude': -69.5}
# Not Found
# OK postalcode 08110: {'city': 'Pennsauken', 'state': 'NJ', 'county': 'Camden', 'latitude': 39.97, 'longitude': -75.06}
# Not Found
# OK postalcode 07980-1529: {'city': 'Stirling', 'state': 'NJ', 'county': 'Morris', 'latitude': 40.67, 'longitude': -74.49}
# OK postalcode 08817: {'city': 'Edison', 'state': 'NJ', 'county': 'Middlesex', 'latitude': 40.52, 'longitude': -74.4}
# Not Found
# OK postalcode 06905-5619: {'city': 'Stamford', 'state': 'CT', 'county': 'Fairfield', 'latitude': 41.1, 'longitude': -73.55}
# OK postalcode 02053: {'city': 'Medway', 'state': 'MA', 'county': 'Norfolk', 'latitude': 42.16, 'longitude': -71.43}
# Not Found
# OK postalcode 05043: {'city': 'East Thetford', 'state': 'VT', 'county': 'Orange', 'latitude': 43.81, 'longitude': -72.22}
# ERROR: 'NoneType' object has no attribute 'find_all'
# OK postalcode 06371: {'city': 'Old Lyme', 'state': 'CT', 'county': 'New London', 'latitude': 41.4, 'longitude': -72.3}
# OK postalcode 06901: {'city': 'Stamford', 'state': 'CT', 'county': 'Fairfield', 'latitude': 41.054, 'longitude': -73.538}
# Not Found
# Not Found
# Not Found
# Not Found
# OK postalcode 02043-4312: {'city': 'Hingham', 'state': 'MA', 'county': 'Plymouth', 'latitude': 42.25, 'longitude': -70.92}
# OK postalcode 02861-1900: {'city': 'Pawtucket', 'state': 'RI', 'county': 'Providence', 'latitude': 41.88, 'longitude': -71.36}
# OK postalcode 08055-1931: {'city': 'Medford', 'state': 'NJ', 'county': 'Burlington', 'latitude': 39.86, 'longitude': -74.8}
# OK postalcode 01510-2005: {'city': 'Clinton', 'state': 'MA', 'county': 'Worcester', 'latitude': 42.42, 'longitude': -71.69}
# OK postalcode 07075: {'city': 'Wood Ridge', 'state': 'NJ', 'county': 'Bergen', 'latitude': 40.85, 'longitude': -74.09}
# OK postalcode 6005: {'city': '', 'state': '', 'county': 'Wellington City', 'latitude': -41.3, 'longitude': 174.7}
# Not Found
# OK postalcode 06226: {'city': 'Willimantic', 'state': 'CT', 'county': 'Windham', 'latitude': 41.7, 'longitude': -72.21}
# Not Found
# Not Found
# Not Found
# OK postalcode 02724: {'city': 'Fall River', 'state': 'MA', 'county': 'Bristol', 'latitude': 41.69, 'longitude': -71.18}
# OK postalcode 07306: {'city': 'Jersey City', 'state': 'NJ', 'county': 'Hudson', 'latitude': 40.74, 'longitude': -74.07}
# OK postalcode 03301: {'city': 'Concord', 'state': 'NH', 'county': 'Merrimack', 'latitude': 43.2, 'longitude': -71.5}
# OK postalcode 04677: {'city': 'Sorrento', 'state': 'ME', 'county': 'Hancock', 'latitude': 44.49, 'longitude': -68.18}
# Not Found
# OK postalcode 08742: {'city': 'Point Pleasant Beach', 'state': 'NJ', 'county': 'Ocean', 'latitude': 40.08, 'longitude': -74.06}
# OK postalcode 03044: {'city': 'Fremont', 'state': 'NH', 'county': 'Rockingham', 'latitude': 42.99, 'longitude': -71.13}
# OK postalcode 04043: {'city': 'Kennebunk', 'state': 'ME', 'county': 'York', 'latitude': 43.4, 'longitude': -70.6}
# OK postalcode 01905: {'city': 'Lynn', 'state': 'MA', 'county': 'Essex', 'latitude': 42.47, 'longitude': -70.97}
# OK postalcode 07032: {'city': 'Kearny', 'state': 'NJ', 'county': 'Hudson', 'latitude': 40.75, 'longitude': -74.12}
# Not Found
# Not Found
# OK postalcode 02379: {'city': 'West Bridgewater', 'state': 'MA', 'county': 'Plymouth', 'latitude': 42.02, 'longitude': -71.02}
# OK postalcode 01615-0036: {'city': 'Worcester', 'state': 'MA', 'county': 'Worcester', 'latitude': 42.26, 'longitude': -71.8}
# OK postalcode 07828: {'city': 'Budd Lake', 'state': 'NJ', 'county': 'Morris', 'latitude': 40.88, 'longitude': -74.75}
# Not Found
# OK postalcode 02453-8425: {'city': 'Waltham', 'state': 'MA', 'county': 'Middlesex', 'latitude': 42.37, 'longitude': -71.23}
# OK postalcode 92326: {'city': 'Crest Park', 'state': 'CA', 'county': 'San Bernardino', 'latitude': 34.2, 'longitude': -117.3}
# Not Found
# OK postalcode 07107-3000: {'city': 'Newark', 'state': 'NJ', 'county': 'Essex', 'latitude': 40.75, 'longitude': -74.19}
# OK postalcode 02186: {'city': 'Milton', 'state': 'MA', 'county': 'Norfolk', 'latitude': 42.24, 'longitude': -71.08}
# OK postalcode 03561: {'city': 'Littleton', 'state': 'NH', 'county': 'Grafton', 'latitude': 44.3, 'longitude': -71.8}
# Not Found
# OK postalcode 03303: {'city': 'Concord', 'state': 'NH', 'county': 'Merrimack', 'latitude': 43.3, 'longitude': -71.7}
# OK postalcode 08536: {'city': 'Plainsboro', 'state': 'NJ', 'county': 'Middlesex', 'latitude': 40.34, 'longitude': -74.58}
# Not Found
# ERROR: 'County'
# OK postalcode 08833: {'city': 'Lebanon', 'state': 'NJ', 'county': 'Hunterdon', 'latitude': 40.64, 'longitude': -74.82}
# Not Found
# OK postalcode 05156: {'city': 'Springfield', 'state': 'VT', 'county': 'Windsor', 'latitude': 43.3, 'longitude': -72.5}
# OK postalcode 02019: {'city': 'Bellingham', 'state': 'MA', 'county': 'Norfolk', 'latitude': 42.08, 'longitude': -71.47}
# OK postalcode 02364: {'city': 'Kingston', 'state': 'MA', 'county': 'Plymouth', 'latitude': 41.98, 'longitude': -70.75}
# OK postalcode 01840: {'city': 'Lawrence', 'state': 'MA', 'county': 'Essex', 'latitude': 42.71, 'longitude': -71.16}
# Not Found
# OK postalcode 08825: {'city': 'Frenchtown', 'state': 'NJ', 'county': 'Hunterdon', 'latitude': 40.51, 'longitude': -75.0}
# Not Found
# OK postalcode 02454: {'city': 'Waltham', 'state': 'MA', 'county': 'Middlesex', 'latitude': 42.37, 'longitude': -71.23}
# Not Found
# OK postalcode 04104: {'city': 'Portland', 'state': 'ME', 'county': 'Cumberland', 'latitude': 43.659, 'longitude': -70.257}
# Not Found
# OK postalcode 07755: {'city': 'Oakhurst', 'state': 'NJ', 'county': 'Monmouth', 'latitude': 40.26, 'longitude': -74.02}
# Not Found
# OK postalcode 06824 USA: {'city': 'Fairfield', 'state': 'CT', 'county': 'Fairfield', 'latitude': 41.14, 'longitude': -73.26}
# Not Found
# OK postalcode 01610: {'city': 'Worcester', 'state': 'MA', 'county': 'Worcester', 'latitude': 42.25, 'longitude': -71.81}
# OK postalcode 02888: {'city': 'Warwick', 'state': 'RI', 'county': 'Kent', 'latitude': 41.75, 'longitude': -71.41}
# OK postalcode 02128: {'city': 'East Boston', 'state': 'MA', 'county': 'Suffolk', 'latitude': 42.37, 'longitude': -71.02}
# OK postalcode 03753: {'city': 'Grantham', 'state': 'NH', 'county': 'Sullivan', 'latitude': 43.51, 'longitude': -72.14}
# OK postalcode 01752-3032: {'city': 'Marlborough', 'state': 'MA', 'county': 'Middlesex', 'latitude': 42.35, 'longitude': -71.55}
# Not Found
# Not Found
# Not Found
# OK postalcode 02780: {'city': 'Taunton', 'state': 'MA', 'county': 'Bristol', 'latitude': 41.91, 'longitude': -71.12}
# OK postalcode 07976: {'city': 'New Vernon', 'state': 'NJ', 'county': 'Morris', 'latitude': 40.73, 'longitude': -74.48}
# OK postalcode 08824: {'city': 'Kendall Park', 'state': 'NJ', 'county': 'Middlesex', 'latitude': 40.42, 'longitude': -74.55}
# OK postalcode 01467: {'city': 'Still River', 'state': 'MA', 'county': 'Worcester', 'latitude': 42.4921, 'longitude': -71.6178}
# Not Found
# Not Found
# OK postalcode 07068: {'city': 'Roseland', 'state': 'NJ', 'county': 'Essex', 'latitude': 40.82, 'longitude': -74.31}
# Not Found
# Not Found
# OK postalcode 5511: {'city': '', 'state': '', 'county': 'Guiyang', 'latitude': 27.1, 'longitude': 106.7}
# OK postalcode 07440: {'city': 'Pequannock', 'state': 'NJ', 'county': 'Morris', 'latitude': 40.95, 'longitude': -74.3}
# OK postalcode 05827: {'city': 'Craftsbury Common', 'state': 'VT', 'county': 'Orleans', 'latitude': 44.68, 'longitude': -72.36}
# OK postalcode 05446: {'city': 'Colchester', 'state': 'VT', 'county': 'Chittenden', 'latitude': 44.6, 'longitude': -73.2}
# OK postalcode 06069: {'city': 'Sharon', 'state': 'CT', 'county': 'Litchfield', 'latitude': 41.86, 'longitude': -73.44}
# Not Found
# OK postalcode 07083-7143: {'city': 'Union', 'state': 'NJ', 'county': 'Union', 'latitude': 40.7, 'longitude': -74.27}
# Not Found
# Not Found
# OK postalcode 06811: {'city': 'Danbury', 'state': 'CT', 'county': 'Fairfield', 'latitude': 41.42, 'longitude': -73.48}
# OK postalcode 07660: {'city': 'Ridgefield Park', 'state': 'NJ', 'county': 'Bergen', 'latitude': 40.86, 'longitude': -74.01}
# OK postalcode 07834: {'city': 'Denville', 'state': 'NJ', 'county': 'Morris', 'latitude': 40.88, 'longitude': -74.49}
# Not Found
# OK postalcode 05404: {'city': 'Winooski', 'state': 'VT', 'county': 'Chittenden', 'latitude': 44.5, 'longitude': -73.18}
# OK postalcode 05201: {'city': 'Bennington', 'state': 'VT', 'county': 'Bennington', 'latitude': 42.9, 'longitude': -73.1}
# OK postalcode 07065-0907: {'city': 'Rahway', 'state': 'NJ', 'county': 'Union', 'latitude': 40.6, 'longitude': -74.29}
# Not Found
# OK postalcode 06817-0001: {'city': 'New Fairfield', 'state': 'CT', 'county': 'Fairfield', 'latitude': 41.46, 'longitude': -73.53}
# OK postalcode 02806: {'city': 'Barrington', 'state': 'RI', 'county': 'Bristol', 'latitude': 41.74, 'longitude': -71.32}
# OK postalcode 95034-7200: {'city': 'Morgan Hill', 'state': 'CA', 'county': 'Santa Clara', 'latitude': 37.1, 'longitude': -121.6}
# ERROR: local variable 'a' referenced before assignment
# OK postalcode 01776: {'city': 'Sudbury', 'state': 'MA', 'county': 'Middlesex', 'latitude': 42.39, 'longitude': -71.42}
# OK postalcode 08502: {'city': 'Belle Mead', 'state': 'NJ', 'county': 'Somerset', 'latitude': 40.44, 'longitude': -74.65}
# OK postalcode 07014: {'city': 'Clifton', 'state': 'NJ', 'county': 'Passaic', 'latitude': 40.83, 'longitude': -74.14}
# Not Found
# OK postalcode 02127: {'city': 'South Boston', 'state': 'MA', 'county': 'Suffolk', 'latitude': 42.33, 'longitude': -71.04}
# OK postalcode 05047: {'city': 'Hartford', 'state': 'VT', 'county': 'Windsor', 'latitude': 43.7, 'longitude': -72.4}
# OK postalcode 01001: {'city': 'Agawam', 'state': 'MA', 'county': 'Hampden', 'latitude': 42.07, 'longitude': -72.63}
# Not Found
# OK postalcode 06095: {'city': 'Windsor', 'state': 'CT', 'county': 'Hartford', 'latitude': 41.87, 'longitude': -72.68}
# OK postalcode US 05829: {'city': 'Derby', 'state': 'VT', 'county': 'Orleans', 'latitude': 44.95, 'longitude': -72.13}
# OK postalcode 07045-0427: {'city': 'Montville', 'state': 'NJ', 'county': 'Morris', 'latitude': 40.89, 'longitude': -74.37}
# OK postalcode 04901: {'city': 'Waterville', 'state': 'ME', 'county': 'Kennebec', 'latitude': 44.6, 'longitude': -69.6}
# OK postalcode 02920: {'city': 'Cranston', 'state': 'RI', 'county': 'Providence', 'latitude': 41.77, 'longitude': -71.47}
# OK postalcode 04679: {'city': 'Southwest Harbor', 'state': 'ME', 'county': 'Hancock', 'latitude': 44.28, 'longitude': -68.34}
# Not Found
# OK postalcode 9310-3056: {'city': 'Austin', 'state': 'NV', 'county': 'Lander', 'latitude': 39.2, 'longitude': -117.1}
# OK postalcode 03431: {'city': 'Keene', 'state': 'NH', 'county': 'Cheshire', 'latitude': 43.0, 'longitude': -72.3}
# Not Found
# OK postalcode 07656: {'city': 'Park Ridge', 'state': 'NJ', 'county': 'Bergen', 'latitude': 41.03, 'longitude': -74.04}
# OK postalcode 06082-4444: {'city': 'Enfield', 'state': 'CT', 'county': 'Hartford', 'latitude': 41.98, 'longitude': -72.55}
# OK postalcode 06032: {'city': 'Farmington', 'state': 'CT', 'county': 'Hartford', 'latitude': 41.73, 'longitude': -72.83}
# Not Found
# OK postalcode 06117: {'city': 'West Hartford', 'state': 'CT', 'county': 'Hartford', 'latitude': 41.78, 'longitude': -72.76}
# OK postalcode 07852: {'city': 'Ledgewood', 'state': 'NJ', 'county': 'Morris', 'latitude': 40.88, 'longitude': -74.66}
# Not Found
# OK postalcode 02655: {'city': 'Osterville', 'state': 'MA', 'county': 'Barnstable', 'latitude': 41.63, 'longitude': -70.39}
# OK postalcode 03854-2039: {'city': 'New Castle', 'state': 'NH', 'county': 'Rockingham', 'latitude': 43.07, 'longitude': -70.72}
# OK postalcode 02702-0896: {'city': 'Assonet', 'state': 'MA', 'county': 'Bristol', 'latitude': 41.79, 'longitude': -71.09}
# OK postalcode 07086: {'city': 'Weehawken', 'state': 'NJ', 'county': 'Hudson', 'latitude': 40.77, 'longitude': -74.02}
# OK postalcode 08812: {'city': 'Dunellen', 'state': 'NJ', 'county': 'Middlesex', 'latitude': 40.61, 'longitude': -74.48}
# OK postalcode 08844: {'city': 'Hillsborough', 'state': 'NJ', 'county': 'Somerset', 'latitude': 40.5, 'longitude': -74.7}
# OK postalcode 08077: {'city': 'Riverton', 'state': 'NJ', 'county': 'Burlington', 'latitude': 40.0, 'longitude': -75.0}
# OK postalcode 07059: {'city': 'Warren', 'state': 'NJ', 'county': 'Somerset', 'latitude': 40.63, 'longitude': -74.51}
# Not Found
# OK postalcode 03903: {'city': 'Eliot', 'state': 'ME', 'county': 'York', 'latitude': 43.15, 'longitude': -70.78}
# OK postalcode 04077: {'city': 'South Casco', 'state': 'ME', 'county': 'Cumberland', 'latitude': 44.0, 'longitude': -70.5}
# OK postalcode 01905-1639: {'city': 'Lynn', 'state': 'MA', 'county': 'Essex', 'latitude': 42.46, 'longitude': -70.97}
# OK postalcode 02881: {'city': 'Kingston', 'state': 'RI', 'county': 'Washington', 'latitude': 41.48, 'longitude': -71.53}
# ERROR: 'NoneType' object has no attribute 'find_all'
# OK postalcode 01434: {'city': 'Devens', 'state': 'MA', 'county': 'Worcester', 'latitude': 42.54, 'longitude': -71.61}
# Not Found
# Not Found
# ERROR: local variable 'a' referenced before assignment
# OK postalcode 05489: {'city': 'Underhill', 'state': 'VT', 'county': 'Chittenden', 'latitude': 44.5, 'longitude': -72.9}
# Not Found
# OK postalcode 01747-0013: {'city': 'Hopedale', 'state': 'MA', 'county': 'Worcester', 'latitude': 42.13, 'longitude': -71.54}
# Not Found
# OK postalcode 07751: {'city': 'Morganville', 'state': 'NJ', 'county': 'Monmouth', 'latitude': 40.36, 'longitude': -74.26}
# Not Found
# OK postalcode 02863: {'city': 'Central Falls', 'state': 'RI', 'county': 'Providence', 'latitude': 41.89, 'longitude': -71.39}
# OK postalcode 07012-1013: {'city': 'Clifton', 'state': 'NJ', 'county': 'Passaic', 'latitude': 40.85, 'longitude': -74.16}
# OK postalcode 01832-1300: {'city': 'Haverhill', 'state': 'MA', 'county': 'Essex', 'latitude': 42.77, 'longitude': -71.09}
# Not Found
# Not Found
# OK postalcode 02420-9192: {'city': 'Lexington', 'state': 'MA', 'county': 'Middlesex', 'latitude': 42.45, 'longitude': -71.22}
# Not Found
# Not Found
# Not Found
# OK postalcode US 07663: {'city': 'Saddle Brook', 'state': 'NJ', 'county': 'Bergen', 'latitude': 40.89, 'longitude': -74.09}
# OK postalcode 03064: {'city': 'Nashua', 'state': 'NH', 'county': 'Hillsborough', 'latitude': 42.78, 'longitude': -71.47}
# OK postalcode 03708-11422: {'city': 'Rosedale', 'state': 'NY', 'county': 'Queens', 'latitude': 40.65, 'longitude': -73.75}
# Not Found
# ERROR: 'County'
# OK postalcode 02472: {'city': 'Watertown', 'state': 'MA', 'county': 'Middlesex', 'latitude': 42.37, 'longitude': -71.18}
# OK postalcode 04037: {'city': 'Fryeburg', 'state': 'ME', 'county': 'Oxford', 'latitude': 44.1, 'longitude': -70.9}
# OK postalcode 06102: {'city': 'Hartford', 'state': 'CT', 'county': 'Hartford', 'latitude': 41.77, 'longitude': -72.67}
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# OK postalcode 02061: {'city': 'Norwell', 'state': 'MA', 'county': 'Plymouth', 'latitude': 42.15, 'longitude': -70.82}
# OK postalcode 08691: {'city': 'Robbinsville', 'state': 'NJ', 'county': 'Mercer', 'latitude': 40.2, 'longitude': -74.6}
# Not Found
# OK postalcode 06051: {'city': 'New Britain', 'state': 'CT', 'county': 'Hartford', 'latitude': 41.67, 'longitude': -72.77}
# Not Found
# Not Found
# Not Found
# Not Found
# OK postalcode 03051-4930: {'city': 'Hudson', 'state': 'NH', 'county': 'Hillsborough', 'latitude': 42.76, 'longitude': -71.44}
# Not Found
# Not Found
# Not Found
# Not Found
# OK postalcode 04941: {'city': 'Freedom', 'state': 'ME', 'county': 'Waldo', 'latitude': 44.5, 'longitude': -69.3}
# OK postalcode 02760: {'city': 'North Attleboro', 'state': 'MA', 'county': 'Bristol', 'latitude': 41.97, 'longitude': -71.32}
# Not Found
# OK postalcode 02921: {'city': 'Cranston', 'state': 'RI', 'county': 'Providence', 'latitude': 41.76, 'longitude': -71.52}
# OK postalcode 05471: {'city': 'Montgomery Center', 'state': 'VT', 'county': 'Franklin', 'latitude': 44.9, 'longitude': -72.6}
# OK postalcode 08629: {'city': 'Trenton', 'state': 'NJ', 'county': 'Mercer', 'latitude': 40.22, 'longitude': -74.73}
# OK postalcode 02459: {'city': 'Newton Center', 'state': 'MA', 'county': 'Middlesex', 'latitude': 42.31, 'longitude': -71.19}
# OK postalcode 01730: {'city': 'Bedford', 'state': 'MA', 'county': 'Middlesex', 'latitude': 42.5, 'longitude': -71.28}
# OK postalcode 03233: {'city': 'Elkins', 'state': 'NH', 'county': 'Merrimack', 'latitude': 43.43, 'longitude': -71.93}
# OK postalcode 06883-2639: {'city': 'Weston', 'state': 'CT', 'county': 'Fairfield', 'latitude': 41.19, 'longitude': -73.37}
# Not Found
# OK postalcode 08543: {'city': 'Princeton', 'state': 'NJ', 'county': 'Mercer', 'latitude': 40.35, 'longitude': -74.66}
# OK postalcode 02208: {'city': '', 'state': '', 'county': 'Suffolk', 'latitude': 42.357, 'longitude': -71.064}
# Not Found
# OK postalcode 06281: {'city': 'Woodstock', 'state': 'CT', 'county': 'Windham', 'latitude': 41.97, 'longitude': -72.01}
# OK postalcode 06484-4697: {'city': 'Shelton', 'state': 'CT', 'county': 'Fairfield', 'latitude': 41.31, 'longitude': -73.09}
# Not Found
# OK postalcode 08535: {'city': 'Millstone Township', 'state': 'NJ', 'county': 'Monmouth', 'latitude': 40.23, 'longitude': -74.45}
# Not Found
# Not Found
# Not Found
# OK postalcode 06450-7195: {'city': 'Meriden', 'state': 'CT', 'county': 'New Haven', 'latitude': 41.53, 'longitude': -72.79}
# ERROR: 'Post Office City'
# OK postalcode 07083: {'city': 'Union', 'state': 'NJ', 'county': 'Union', 'latitude': 40.69, 'longitude': -74.27}
# Not Found
# OK postalcode 04032: {'city': 'Freeport', 'state': 'ME', 'county': 'Cumberland', 'latitude': 43.86, 'longitude': -70.1}
# Not Found
# OK postalcode 01851: {'city': 'Lowell', 'state': 'MA', 'county': 'Middlesex', 'latitude': 42.62, 'longitude': -71.34}
# OK postalcode 95314: {'city': 'Pinecrest', 'state': 'CA', 'county': 'Tuolumne', 'latitude': 38.3, 'longitude': -119.9}
# OK postalcode 05363: {'city': 'Wilmington', 'state': 'VT', 'county': 'Windham', 'latitude': 42.9, 'longitude': -72.9}
# OK postalcode 08810: {'city': 'Dayton', 'state': 'NJ', 'county': 'Middlesex', 'latitude': 40.37, 'longitude': -74.5}
# OK postalcode 02557: {'city': 'Oak Bluffs', 'state': 'MA', 'county': 'Dukes', 'latitude': 41.454, 'longitude': -70.562}
# OK postalcode 03766: {'city': 'Lebanon', 'state': 'NH', 'county': 'Grafton', 'latitude': 43.63, 'longitude': -72.24}
# OK postalcode 03602: {'city': 'Alstead', 'state': 'NH', 'county': 'Cheshire', 'latitude': 43.1, 'longitude': -72.3}
# OK postalcode 03073-0097: {'city': 'Salem', 'state': 'NH', 'county': 'Rockingham', 'latitude': 42.83, 'longitude': -71.23}
# OK postalcode 06751: {'city': 'Bethlehem', 'state': 'CT', 'county': 'Litchfield', 'latitude': 41.64, 'longitude': -73.21}
# OK postalcode 05454: {'city': 'Fairfax', 'state': 'VT', 'county': 'Franklin', 'latitude': 44.71, 'longitude': -73.02}
# OK postalcode 07120: {'city': '', 'state': '', 'county': 'Ardeche', 'latitude': 44.5, 'longitude': 4.3}
# OK postalcode USA 08873: {'city': 'Somerset', 'state': 'NJ', 'county': 'Somerset', 'latitude': 40.49, 'longitude': -74.48}
# OK postalcode 01583: {'city': 'West Boylston', 'state': 'MA', 'county': 'Worcester', 'latitude': 42.36, 'longitude': -71.78}
# Not Found
# OK postalcode US 07733: {'city': 'Holmdel', 'state': 'NJ', 'county': 'Monmouth', 'latitude': 40.39, 'longitude': -74.15}
# OK postalcode 01254: {'city': 'Richmond', 'state': 'MA', 'county': 'Berkshire', 'latitude': 42.38, 'longitude': -73.37}
# OK postalcode 08873: {'city': 'Somerset', 'state': 'NJ', 'county': 'Somerset', 'latitude': 40.5, 'longitude': -74.52}
# Not Found
# OK postalcode 02556: {'city': 'North Falmouth', 'state': 'MA', 'county': 'Barnstable', 'latitude': 41.64, 'longitude': -70.63}
# OK postalcode 01721: {'city': 'Ashland', 'state': 'MA', 'county': 'Middlesex', 'latitude': 42.26, 'longitude': -71.47}
# Not Found
# Not Found
# OK postalcode 06419: {'city': 'Killingworth', 'state': 'CT', 'county': 'Middlesex', 'latitude': 41.38, 'longitude': -72.58}
# OK postalcode 06525-2330: {'city': 'Woodbridge', 'state': 'CT', 'county': 'New Haven', 'latitude': 41.34, 'longitude': -72.99}
# OK postalcode 08302: {'city': 'Bridgeton', 'state': 'NJ', 'county': 'Cumberland', 'latitude': 39.4, 'longitude': -75.3}
# OK postalcode 04463: {'city': 'Milo', 'state': 'ME', 'county': 'Piscataquis', 'latitude': 45.3, 'longitude': -68.9}
# OK postalcode 07962-9806: {'city': 'Morristown', 'state': 'NJ', 'county': 'Morris', 'latitude': 40.8, 'longitude': -74.46}

# %%
new_data = pd.DataFrame.from_dict(cod, orient="index")
new_data["postcode"] = new_data.index
new_data.reset_index(drop=True, inplace=True)

# %%
new_data.to_csv("/mxxx/new_county.csv", index=False)

# %%
pd.merge(data, new_data, on="postcode", how="left")
# Out:
#        patent_id       city_x        state_x     county_x postcode  \
# 0       10000015          NaN  MASSACHUSETTS    MIDDLESEX    02421
# 1       10000042       NEWARK           OHIO      LICKING    43055
# 2       10000042     COLUMBUS           OHIO     FRANKLIN    43215
# 3       10000042     COLUMBUS           OHIO     DELAWARE    43215
# 4       10000053          NaN  NEW HAMPSHIRE    STRAFFORD    03824
# ...          ...          ...            ...          ...      ...
# 440852   RE48184          NaN  MASSACHUSETTS      BRISTOL    02767
# 440853   RE48193  SCHENECTADY       NEW YORK  SCHENECTADY    12309
# 440854   RE48247    SAN DIEGO     CALIFORNIA    SAN DIEGO    92121
# 440855   RE48247          NaN  MASSACHUSETTS    MIDDLESEX    02472
# 440856   RE48251          NaN  MASSACHUSETTS      BRISTOL    02767
#
#         postcode_clean     lats_x      lngs_x    county1     city_y state_y  \
# 0               2421.0        NaN         NaN  MIDDLESEX  Lexington      MA
# 1              43055.0  40.072399  -82.404602        NaN        NaN     NaN
# 2              43215.0  39.967098  -83.004402        NaN        NaN     NaN
# 3              43215.0  39.967098  -83.004402        NaN        NaN     NaN
# 4               3824.0        NaN         NaN  STRAFFORD        NaN     NaN
# ...                ...        ...         ...        ...        ...     ...
# 440852          2767.0        NaN         NaN    BRISTOL    Raynham      MA
# 440853         12309.0  42.809101  -73.869301        NaN        NaN     NaN
# 440854         92121.0  32.891899 -117.203500  MIDDLESEX        NaN     NaN
# 440855          2472.0        NaN         NaN  MIDDLESEX  Watertown      MA
# 440856          2767.0        NaN         NaN    BRISTOL    Raynham      MA
#
#          county_y latitude longitude
# 0       Middlesex    42.44    -71.23
# 1             NaN      NaN       NaN
# 2             NaN      NaN       NaN
# 3             NaN      NaN       NaN
# 4             NaN      NaN       NaN
# ...           ...      ...       ...
# 440852    Bristol    41.94    -71.06
# 440853        NaN      NaN       NaN
# 440854        NaN      NaN       NaN
# 440855  Middlesex    42.37    -71.18
# 440856    Bristol    41.94    -71.06
#
# [440857 rows x 14 columns]
